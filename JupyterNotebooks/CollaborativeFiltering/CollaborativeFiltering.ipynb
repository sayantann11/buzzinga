# %% [markdown]
# ## Nearest Neighbours Collaborative Filtering System

# %%
import numpy as np
import pandas as pd
from scipy.sparse import csr_matrix

# %%
#LOADING DATASETS
movies = pd.read_csv('../../Datasets/movies.csv',index_col=[0])
ratings =pd.read_csv('../../Datasets/ratings.csv')
links = pd.read_csv('../../Datasets/links.csv',index_col=[0]).set_index('movieId')['imdb_link']
movieId = movies[["movieId", "title"]].set_index("title")
movieTitle = movies[["movieId","title"]].set_index("movieId")

# %%
movies[movies['movieId']==34048]
# Out:
#       movieId                     title                            genres
# 5931    34048  War of the Worlds (2005)  Action|Adventure|Sci-Fi|Thriller

# %%
links.head()
# Out:
# movieId
# 1    https://www.imdb.com/title/tt0114709
# 2    https://www.imdb.com/title/tt0113497
# 3    https://www.imdb.com/title/tt0113228
# 4    https://www.imdb.com/title/tt0114885
# 5    https://www.imdb.com/title/tt0113041
# Name: imdb_link, dtype: object

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
##COMBINING DATASETS
ratings = pd.merge(movies, ratings).drop(
            ["genres", "timestamp"], axis=1
        )
ratings[ratings['movieId']==34049]
# Out:
# Empty DataFrame
# Columns: [movieId, title, userId, rating]
# Index: []

# %%
ratings[ratings['movieId']==64997]
# Out:
#        movieId                     title  userId  rating
# 88672    64997  War of the Worlds (2005)      28     3.5
# 88673    64997  War of the Worlds (2005)      68     2.5

# %%
ratings = ratings.dropna(thresh=10, axis=1).fillna(
            0, axis=1
        )
ratings.fillna(0, axis=1, inplace=True)
ratings.head()
# Out:
#    movieId             title  userId  rating
# 0        1  Toy Story (1995)       1     4.0
# 1        1  Toy Story (1995)       5     4.0
# 2        1  Toy Story (1995)       7     4.5
# 3        1  Toy Story (1995)      15     2.5
# 4        1  Toy Story (1995)      17     4.5

# %%
movies_ratings = ratings.pivot_table(
            index=["userId"], columns=["movieId"], values="rating"
        )
movies_ratings = movies_ratings.dropna(thresh=10, axis=1).fillna(
            0, axis=1
        )
movies_ratings.fillna(0, axis=1, inplace=True)

# %%
corr_matrix = movies_ratings.corr(method="pearson")
corr_matrix
# Out:
# movieId    1         2         3         5         6         7         9       \
# movieId
# 1        1.000000  0.231327  0.173213  0.192474  0.192686  0.143743  0.177245
# 2        0.231327  1.000000  0.191945  0.200526  0.158341  0.127569 -0.021045
# 3        0.173213  0.191945  1.000000  0.370171  0.196442  0.351513  0.275812
# 5        0.192474  0.200526  0.370171  1.000000  0.215503  0.429890  0.308085
# 6        0.192686  0.158341  0.196442  0.215503  1.000000  0.148109  0.167909
# ...           ...       ...       ...       ...       ...       ...       ...
# 174055   0.059796  0.060834  0.044769 -0.003536  0.078585  0.041336  0.014197
# 176371   0.054642  0.150281  0.033825  0.000280  0.119709  0.029589 -0.001716
# 177765  -0.013607 -0.020637 -0.039794 -0.038865 -0.060090 -0.040824 -0.021576
# 179819   0.053028  0.113709  0.026881 -0.000983  0.015800  0.010491 -0.020035
# 187593   0.022160  0.118390 -0.039206 -0.038291  0.038239 -0.040222 -0.021257
#
# movieId    10        11        12      ...    166461    166528    166643  \
# movieId                                ...
# 1        0.183382  0.172799  0.159352  ... -0.003950  0.070499  0.111588
# 2        0.285086  0.217090  0.115290  ...  0.047793  0.167779  0.049701
# 3        0.136916  0.174251  0.168038  ... -0.035086  0.000094  0.018855
# 5        0.110833  0.201002  0.173630  ...  0.029139  0.006434 -0.005243
# 6        0.251343  0.182082  0.115893  ... -0.052982  0.106208  0.006448
# ...           ...       ...       ...  ...       ...       ...       ...
# 174055  -0.009848  0.042380  0.017650  ...  0.096152  0.184902  0.282894
# 176371   0.032775  0.041955  0.083686  ...  0.132310  0.434742  0.362638
# 177765  -0.031616 -0.035557 -0.021954  ...  0.237951  0.143826  0.085723
# 179819  -0.028194  0.041405 -0.005968  ...  0.181528  0.468824  0.396642
# 187593   0.014762 -0.013474  0.052391  ...  0.108441  0.337844  0.198631
#
# movieId    168250    168252    174055    176371    177765    179819    187593
# movieId
# 1        0.022451  0.066439  0.059796  0.054642 -0.013607  0.053028  0.022160
# 2        0.036534  0.195111  0.060834  0.150281 -0.020637  0.113709  0.118390
# 3       -0.031249 -0.000959  0.044769  0.033825 -0.039794  0.026881 -0.039206
# 5       -0.004671 -0.022762 -0.003536  0.000280 -0.038865 -0.000983 -0.038291
# 6        0.038345  0.123248  0.078585  0.119709 -0.060090  0.015800  0.038239
# ...           ...       ...       ...       ...       ...       ...       ...
# 174055   0.341528  0.325772  1.000000  0.689737  0.127251  0.284834  0.128020
# 176371   0.368046  0.476659  0.689737  1.000000  0.169473  0.495133  0.382127
# 177765   0.171565  0.062448  0.127251  0.169473  1.000000  0.362601  0.345148
# 179819   0.299374  0.493593  0.284834  0.495133  0.362601  1.000000  0.466643
# 187593   0.215818  0.320234  0.128020  0.382127  0.345148  0.466643  1.000000
#
# [2269 rows x 2269 columns]

# %%
def recommend(user_ratings):
        if len(user_ratings) == 0:
            return []
        movies_list = []
        ratings_list = []
        for movie, rating in user_ratings:
            movies_list.append(movieId.loc[movie]['movieId'])
            ratings_list.append(rating)
        similar_movies = corr_matrix[movies_list]
        for i in range(len(ratings_list)):
            similar_movies.iloc[
                :, similar_movies.columns.get_loc(movies_list[i])
            ] = similar_movies[movies_list[i]] * (ratings_list[i] - 2.5)
        similar_movies = pd.DataFrame(
            similar_movies.sum(axis=1).sort_values(ascending=False)
        )
        similar_movies["title"] = [
            movieTitle.loc[movie_id]["title"] for movie_id in list(similar_movies.index)
        ]
#         similar_movies.sum().sort_values(ascending=False).head(20)
        return pd.concat(
            [
                similar_movies.head(30)["title"],
                links,
            ],
            axis=1,
            join="inner",
        )

# %%
recommend([['Batman Begins (2005)',5]])
# sim = pd.DataFrame((corr_matrix[['Batman Begins (2005)']]*(2.5)).sum(axis=1).sort_values(ascending=False))

# sim = corr_matrix[[movieId.loc['Batman Begins (2005)']['movieId']]]
# sim = pd.DataFrame(sim.sum(axis=1).sort_values(ascending=False))
# sim["title"] = [movieTitle.loc[movieId]['title'] for movieId in list(sim.index)]

# pd.concat(
#             [
#                 sim.head(30)["title"],
#                 links,
#             ],
#             axis=1,
#             join="inner",
#         )
# Out:
#                                                      title  \
# movieId
# 33794                                 Batman Begins (2005)
# 32587                                      Sin City (2005)
# 58559                               The Dark Knight (2008)
# 44191                                V for Vendetta (2006)
# 6539     Pirates of the Caribbean: The Curse of the Bla...
# 6365                            The Matrix Reloaded (2003)
# 7438                              Kill Bill: Vol. 2 (2004)
# 48780                                  The Prestige (2006)
# 6874                              Kill Bill: Vol. 1 (2003)
# 8961                                The Incredibles (2004)
# 7153     The Lord of the Rings: The Return of the King ...
# 59315                                      Iron Man (2008)
# 49272                                 Casino Royale (2006)
# 51662                                           300 (2007)
# 48516                                  The Departed (2006)
# 45499                         X-Men: The Last Stand (2006)
# 45722    Pirates of the Caribbean: Dead Man's Chest (2006)
# 5952          The Lord of the Rings: The Two Towers (2002)
# 4993     The Lord of the Rings: The Fellowship of the R...
# 5418                            The Bourne Identity (2002)
# 91529                         The Dark Knight Rises (2012)
# 8636                                   Spider-Man 2 (2004)
# 54286                          The Bourne Ultimatum (2007)
# 6333                               X2: X-Men United (2003)
# 8644                                       I, Robot (2004)
# 8665                           The Bourne Supremacy (2004)
# 34048                             War of the Worlds (2005)
# 5502                                          Signs (2002)
# 6934                         The Matrix Revolutions (2003)
# 51255                                      Hot Fuzz (2007)
#
#                                     imdb_link
# movieId
# 33794    https://www.imdb.com/title/tt0372784
# 32587    https://www.imdb.com/title/tt0401792
# 58559    https://www.imdb.com/title/tt0468569
# 44191    https://www.imdb.com/title/tt0434409
# 6539     https://www.imdb.com/title/tt0325980
# 6365     https://www.imdb.com/title/tt0234215
# 7438     https://www.imdb.com/title/tt0378194
# 48780    https://www.imdb.com/title/tt0482571
# 6874     https://www.imdb.com/title/tt0266697
# 8961     https://www.imdb.com/title/tt0317705
# 7153     https://www.imdb.com/title/tt0167260
# 59315    https://www.imdb.com/title/tt0371746
# 49272    https://www.imdb.com/title/tt0381061
# 51662    https://www.imdb.com/title/tt0416449
# 48516    https://www.imdb.com/title/tt0407887
# 45499    https://www.imdb.com/title/tt0376994
# 45722    https://www.imdb.com/title/tt0383574
# 5952     https://www.imdb.com/title/tt0167261
# 4993     https://www.imdb.com/title/tt0120737
# 5418     https://www.imdb.com/title/tt0258463
# 91529    https://www.imdb.com/title/tt1345836
# 8636     https://www.imdb.com/title/tt0316654
# 54286    https://www.imdb.com/title/tt0440963
# 6333     https://www.imdb.com/title/tt0290334
# 8644     https://www.imdb.com/title/tt0343818
# 8665     https://www.imdb.com/title/tt0372183
# 34048    https://www.imdb.com/title/tt0407304
# 5502     https://www.imdb.com/title/tt0286106
# 6934     https://www.imdb.com/title/tt0242653
# 51255    https://www.imdb.com/title/tt0425112
